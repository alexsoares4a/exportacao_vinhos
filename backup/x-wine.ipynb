# %%
import pandas as pd

# %% [markdown]
# # X-Wines Slim
#
# https://www.kaggle.com/datasets/rogerioxavier/x-wines-slim-version?resource=download
#
# X-Wines é um novo e consistente conjunto de dados sobre vinhos contendo 100.646 instâncias com imagens de rótulos e 21 milhões de avaliações reais realizadas por usuários. Os dados foram coletados na Web aberta em 2022 e pré-processados para uso livre mais amplo. Eles referem-se às avaliações na escala de 1 a 5 realizadas durante um período de 10 anos (2012–2021) para vinhos produzidos em 62 países diferentes. Você está convidado a acessar a plataforma colaborativa do Projeto X-Wines em https://sites.google.com/farroupilha.ifrs.edu.br/xwines

# %%
url = "dados/XWines_Slim_1K_wines.csv"

xwines = pd.read_csv(url)

xwines.head(3)
# Out:
#    WineID            WineName       Type      Elaborate  \
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%
# 1  100002          Ancellotta        Red  Varietal/100%
# 2  100003  Cabernet Sauvignon        Red  Varietal/100%
#
#                    Grapes                                          Harmonize  \
# 0      ['Muscat/Moscato']                 ['Pork', 'Rich Fish', 'Shellfish']
# 1          ['Ancellotta']  ['Beef', 'Barbecue', 'Codfish', 'Pasta', 'Pizz...
# 2  ['Cabernet Sauvignon']                        ['Beef', 'Lamb', 'Poultry']
#
#     ABV           Body Acidity Code Country  RegionID    RegionName  WineryID  \
# 0   7.5  Medium-bodied    High   BR  Brazil      1001  Serra Gaúcha     10001
# 1  12.0  Medium-bodied  Medium   BR  Brazil      1001  Serra Gaúcha     10001
# 2  12.0    Full-bodied    High   BR  Brazil      1001  Serra Gaúcha     10002
#
#      WineryName                                 Website  \
# ...

# %%
xwines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   WineID      1007 non-null   int64
#  1   WineName    1007 non-null   object
#  2   Type        1007 non-null   object
#  3   Elaborate   1007 non-null   object
#  4   Grapes      1007 non-null   object
#  5   Harmonize   1007 non-null   object
#  6   ABV         1007 non-null   float64
#  7   Body        1007 non-null   object
#  8   Acidity     1007 non-null   object
#  9   Code        1007 non-null   object
#  10  Country     1007 non-null   object
#  11  RegionID    1007 non-null   int64
#  12  RegionName  1007 non-null   object
#  13  WineryID    1007 non-null   int64
#  14  WineryName  1007 non-null   object
#  15  Website     900 non-null    object
#  16  Vintages    1007 non-null   object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 133.9+ KB
